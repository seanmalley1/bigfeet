# %%
import pandas as pd
# df = pd.read_csv('C:\\Users\\seanm\\Proton Drive\\sean.malley1\\Other computers\\EXACTLY5CATS\\d10\\Projects\\bigfoots-ufos-ghosts-oh-my\\data\\bfro_reports_geocoded.csv')
df = pd.read_csv('F:\\d10\\Projects\\bigfoots-ufos-ghosts-oh-my\\data\\bfro_reports_geocoded.csv')

# %%
cleaned_df = df.dropna(subset=['latitude', 'longitude'])

# %%
import folium


cleaned_df = df.dropna(subset=['location', 'latitude', 'longitude'])
# 200 points at first because computer froze last time 
num_rows = min(500, len(cleaned_df))


if not cleaned_df.empty:
    first_point = cleaned_df.iloc[0]
    m = folium.Map(location=[first_point['latitude'], first_point['longitude']], zoom_start=5)

    # 1st 200 rows to be marked
    for index, row in cleaned_df.iloc[:num_rows].iterrows():
        folium.Marker(location=[row['latitude'], row['longitude']]).add_to(m)

  

    
    display(m)
else:
    print("you messed up, buddy.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c28b3ebf13619dd8f3a999157d05ad0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c28b3ebf13619dd8f3a999157d05ad0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c28b3ebf13619dd8f3a999157d05ad0 = L.map(
#                 &quot;map_9c28b3ebf13619dd8f3a999157d05ad0&quot;,
#                 {
#                     center: [37.58135, -81.29745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7124cda7d223d5f3c85140451f670977 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_70a9ebd943b8b01a8935ce3bcfedbdee = L.marker(
#                 [37.58135, -81.29745],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_7808e5462f8e99e99dc782ae2c356e36 = L.marker(
#                 [43.4654, -72.7051],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_a10ee0320ed422b8902a5ebcf395dd95 = L.marker(
#                 [37.22647, -81.09017],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_d1dcc965eaafdf7428614b54374ffb4a = L.marker(
#                 [32.7943, -95.5425],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_e186a7610371e5eac90fc8f7af01c35c = L.marker(
#                 [41.45, -71.5],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_1499c1453bf59669460074bf9cc68570 = L.marker(
#                 [35.3011, -99.1702],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_440a3f08e7bc6095438fe56807b5ef3e = L.marker(
#                 [39.38745, -81.67339],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_f52d256e3a211a39435070d32828aa9a = L.marker(
#                 [41.29873, -73.73717],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_6a43e962bfe5886abc0bbe1a83c60203 = L.marker(
#                 [39.40877, -81.73172],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_a69b46b64b29bd7c3507ba35b533477a = L.marker(
#                 [39.54739, -81.39101],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_12dc4ce1653cb8476218fe7905ec697b = L.marker(
#                 [39.46019, -81.54855],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_efa7e36ff13da7d386dd6a862da1af62 = L.marker(
#                 [39.3731, -81.65929],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_2d8d79bfe2e7305e9b6395343579282a = L.marker(
#                 [39.42635, -81.37085],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_b16ca9092854c164fdb4697f57fb785c = L.marker(
#                 [41.432, -71.65183],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_a1bd1dfc35ad444ef3584a6abc7426e8 = L.marker(
#                 [41.4596, -71.58906],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_d2514dab3e2c86a45b81ac11a17bb859 = L.marker(
#                 [35.0591, -81.11742],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_70df82e78dea72a1f034fd6cc6c9ad66 = L.marker(
#                 [35.9978, -86.2011],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_04cdb356c19af6106de3bcec0f545c51 = L.marker(
#                 [36.25466, -86.15759],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_efc6ede6e80286389e5e078b33f9b9c6 = L.marker(
#                 [32.69028, -95.61056],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_f11d7497d30bf493089ae99b94c20a64 = L.marker(
#                 [32.85232, -95.46671],
#                 {}
#             ).addTo(map_9c28b3ebf13619dd8f3a999157d05ad0);
#
#
#             var marker_1e2dc5bf8953c37cb42cd724befe7fd5 = L.marker(
#                 [41.5, -111.75],
#                 {}

# %%
import folium

cleaned_df = df.dropna(subset=['location', 'latitude', 'longitude'])

num_rows = min(500, len(cleaned_df))

if not cleaned_df.empty:
    first_point = cleaned_df.iloc[0]
    m = folium.Map(location=[first_point['latitude'], first_point['longitude']], zoom_start=5)

 
    for index, row in cleaned_df.iloc[:num_rows].iterrows():
        folium.Marker(location=[row['latitude'], row['longitude']]).add_to(m)


    display(m)
else:
    print("You messed up, buddy.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_beb5db0354e9c697c9ff04c54c54944c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_beb5db0354e9c697c9ff04c54c54944c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_beb5db0354e9c697c9ff04c54c54944c = L.map(
#                 &quot;map_beb5db0354e9c697c9ff04c54c54944c&quot;,
#                 {
#                     center: [37.58135, -81.29745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a205ff9bba699718ee4bcc1263d2384 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_f8939a323040d34198cd4e53cc322270 = L.marker(
#                 [37.58135, -81.29745],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_f4cae343b008e61b588d0fce856f6e4e = L.marker(
#                 [43.4654, -72.7051],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_ac046353c41550a0c914034cc84da30f = L.marker(
#                 [37.22647, -81.09017],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_070fdaf8f730dc8f2ca9d9684d78bcac = L.marker(
#                 [32.7943, -95.5425],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_95b6a725f04513e0a3cff49ac49a7369 = L.marker(
#                 [41.45, -71.5],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_916f9a7cfc15f7651373a680b6e91e8d = L.marker(
#                 [35.3011, -99.1702],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_a74a1f6a47d5c09c331b4dffba4fc3ae = L.marker(
#                 [39.38745, -81.67339],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_d721c316ec47eb49592c8ee716aa76d7 = L.marker(
#                 [41.29873, -73.73717],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_6cfc29f51625477929cd19e1f1400aac = L.marker(
#                 [39.40877, -81.73172],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_7d77c55d5bfde76f4a8974857704504b = L.marker(
#                 [39.54739, -81.39101],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_e9899da3d433860749af05736bcef2c0 = L.marker(
#                 [39.46019, -81.54855],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_433e1c475f1f212082a033e8c18dc826 = L.marker(
#                 [39.3731, -81.65929],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_7a878c636ff5bf6c946d7ec7e7a96216 = L.marker(
#                 [39.42635, -81.37085],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_2e751a79cc01f42f3f54f163e4308bb6 = L.marker(
#                 [41.432, -71.65183],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_1bfe86a65650a7c4df755c27951ccece = L.marker(
#                 [41.4596, -71.58906],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_e9efc58660523ef80d939759af458d77 = L.marker(
#                 [35.0591, -81.11742],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_3dcfcc49b8f383591f2efdbca2d51cdd = L.marker(
#                 [35.9978, -86.2011],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_f3ca8cdbc867b15f330eaa5df554dd9e = L.marker(
#                 [36.25466, -86.15759],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_e386b5cd26597880ca86c75d67cabb14 = L.marker(
#                 [32.69028, -95.61056],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_72941273ae04db118e4833391754e3e3 = L.marker(
#                 [32.85232, -95.46671],
#                 {}
#             ).addTo(map_beb5db0354e9c697c9ff04c54c54944c);
#
#
#             var marker_21b3b78a8fc2f13eccb37f90ed1d0815 = L.marker(
#                 [41.5, -111.75],
#                 {}

# %%
# def clean_data(df):
    
#     # df = df[df['state'] == "Maine"]
    
#     df = df.groupby(['state']).agg(state_count=('state', 'count')).reset_index()
#     return df

# df_clean = clean_data(df.copy())
# df_clean.head(49)

def clean_data(df_clean):
    
    df_clean = df_clean.sort_values(['state_count'], ascending=[False])
    return df_clean

df_clean_1 = clean_data(df_clean.copy())
df_clean_1.head(55)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 16
#      13     df_clean = df_clean.sort_values(['state_count'], ascending=[False])
#      14     return df_clean
# ---> 16 df_clean_1 = clean_data(df_clean.copy())
#      17 df_clean_1.head(55)
#
# NameError: name 'df_clean' is not defined

# %%
df.head()
# Out:
#                                             observed  \
# 0  I am not sure how relevant this report will be...
# 1  I don't know if what I saw was two bigfoots or...
# 2  My family and I went to Ludlow, Vermont for Co...
# 3  It was spring break 1984 and I was 16 at the t...
# 4  It was the winter of 1996 and we were on our w...
#
#                                     location_details           county  \
# 0  We were on our way to Rapid City, so we were h...  Washakie County
# 1  Heading to the deep mine Poca #2, the airshaft...   Wyoming County
# 2  It's off Rt 100 outside of Ludlow Vermont. It ...   Windsor County
# 3  Wythe county Virginia near Wytheville, looking...     Wythe County
# 4  Hwy 182, Wood County Between Quitman, Texas an...      Wood County
#
#            state  season                                              title  \
# 0        Wyoming  Summer                                                NaN
# 1  West Virginia  Winter  Report 13237: Daylight sighting near an abando...
# 2        Vermont    Fall  Report 13285: Evening sighting by motorists on...
# 3       Virginia  Spring  Report 2285: Boy sees "Bigfoot" in the woods w...
# 4          Texas  Winter  Report 2048: Night time road crossing observation
#
#    latitude  longitude        date   number  ... precip_probability  \
# 0       NaN        NaN         NaN    798.0  ...                NaN
# 1  37.58135  -81.29745  2005-12-03  13237.0  ...              100.0
# 2  43.46540  -72.70510  2005-10-08  13285.0  ...              100.0
# 3  37.22647  -81.09017  1984-04-08   2285.0  ...                0.0
# 4  32.79430  -95.54250  1996-12-22   2048.0  ...                0.0
#
#         precip_type  pressure  \
# 0               NaN       NaN
# 1  ['rain', 'snow']    1018.7
# 2          ['rain']    1011.8
# 3               NaN    1020.9
# 4               NaN       NaN
#
#                                              summary  \
# 0                                                NaN
# 1  Partly cloudy throughout the day with late aft...
# 2  Cloudy skies throughout the day with a chance ...
# 3                  Partly cloudy throughout the day.
# 4                  Partly cloudy throughout the day.
#
#                      conditions  uv_index  visibility  wind_bearing  \
# 0                           NaN       NaN         NaN           NaN
# 1  Snow, Rain, Partially cloudy       NaN         9.3         168.1
# 2                Rain, Overcast       NaN         5.0         356.2
# 3              Partially cloudy       NaN        13.0         107.3
# 4              Partially cloudy       NaN        10.5         180.4
#
#    wind_speed                   location
# 0         NaN                        NaN
# 1        17.1  POINT(-81.29745 37.58135)
# 2         7.6    POINT(-72.7051 43.4654)
# 3        11.5  POINT(-81.09017 37.22647)
# 4        20.8    POINT(-95.5425 32.7943)
#
# [5 rows x 30 columns]

# %%
def clean_data(df):
    
    df = df[df['state'] == "ohio"]
   
    df = df.groupby(['state']).agg(state_count=('state', 'count')).reset_index()
    return df

df_clean = clean_data(df.copy())
df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     df = df.groupby(['state']).agg(state_count=('state', 'count')).reset_index()
#       6     return df
# ----> 8 df_clean = clean_data(df.copy())
#       9 df_clean.head()
#
# NameError: name 'df' is not defined

# %%
cleaned_df.head()
# Out:
#                                             observed  \
# 1  I don't know if what I saw was two bigfoots or...
# 2  My family and I went to Ludlow, Vermont for Co...
# 3  It was spring break 1984 and I was 16 at the t...
# 4  It was the winter of 1996 and we were on our w...
# 7  While attending U.R.I in the Fall of 1974,I wo...
#
#                                     location_details             county  \
# 1  Heading to the deep mine Poca #2, the airshaft...     Wyoming County
# 2  It's off Rt 100 outside of Ludlow Vermont. It ...     Windsor County
# 3  Wythe county Virginia near Wytheville, looking...       Wythe County
# 4  Hwy 182, Wood County Between Quitman, Texas an...        Wood County
# 7             Great swamp area, Narragansett Indians  Washington County
#
#            state  season                                              title  \
# 1  West Virginia  Winter  Report 13237: Daylight sighting near an abando...
# 2        Vermont    Fall  Report 13285: Evening sighting by motorists on...
# 3       Virginia  Spring  Report 2285: Boy sees "Bigfoot" in the woods w...
# 4          Texas  Winter  Report 2048: Night time road crossing observation
# 7   Rhode Island    Fall  Report 6496: Bicycling student has night encou...
#
#    latitude  longitude        date   number  ... precip_probability  \
# 1  37.58135  -81.29745  2005-12-03  13237.0  ...              100.0
# 2  43.46540  -72.70510  2005-10-08  13285.0  ...              100.0
# 3  37.22647  -81.09017  1984-04-08   2285.0  ...                0.0
# 4  32.79430  -95.54250  1996-12-22   2048.0  ...                0.0
# 7  41.45000  -71.50000  1974-09-20   6496.0  ...                0.0
#
#         precip_type  pressure  \
# 1  ['rain', 'snow']    1018.7
# 2          ['rain']    1011.8
# 3               NaN    1020.9
# 4               NaN       NaN
# 7               NaN    1020.6
#
#                                              summary  \
# 1  Partly cloudy throughout the day with late aft...
# 2  Cloudy skies throughout the day with a chance ...
# 3                  Partly cloudy throughout the day.
# 4                  Partly cloudy throughout the day.
# 7                   Cloudy skies throughout the day.
#
#                      conditions  uv_index  visibility  wind_bearing  \
# 1  Snow, Rain, Partially cloudy       NaN         9.3         168.1
# 2                Rain, Overcast       NaN         5.0         356.2
# 3              Partially cloudy       NaN        13.0         107.3
# 4              Partially cloudy       NaN        10.5         180.4
# 7                      Overcast       NaN         2.6         196.6
#
#    wind_speed                   location
# 1        17.1  POINT(-81.29745 37.58135)
# 2         7.6    POINT(-72.7051 43.4654)
# 3        11.5  POINT(-81.09017 37.22647)
# 4        20.8    POINT(-95.5425 32.7943)
# 7        15.0         POINT(-71.5 41.45)
#
# [5 rows x 30 columns]

# %%
cleaned_df['date'] = pd.to_datetime(df['date'], errors='coerce')
df_2010 = cleaned_df[cleaned_df['date'].dt.year == 2010]
# Out:
# C:\Users\seanm\AppData\Local\Temp\ipykernel_8772\265432436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df_2010.head()
# Out:
#                                               observed  \
# 12   Well last year I was night fishing 9/2010 at A...
# 24   Yesterday,I ,my dad,my son,and his Friend, wen...
# 142  I was driving on a backroad in Rhinebeck, NY. ...
# 150  Bigfoot Sighting Date: Early August 2010 Time:...
# 156  My friend and I finished preparing for a big o...
#
#                                       location_details              county  \
# 12   Both sightings were on the North east corner o...  Westchester County
# 24                       Rural Wilson County Tennessee       Wilson County
# 142  From the Rhinecliff Bridge heading towards Rhi...     Dutchess County
# 150                                       Cascade Lake        Essex County
# 156                      (Specific directions omitted)     Hamilton County
#
#          state  season                                              title  \
# 12    New York    Fall  Report 31940: Fishermen and Law Enforcement Of...
# 24   Tennessee  Summer  Report 28005: Two witnesses recount a close da...
# 142   New York  Summer  Report 26205: Young adult has daylight visual ...
# 150   New York  Summer  Report 64192: Camper describes morning sightin...
# 156   New York    Fall  Report 28570: Possible nighttime encounter out...
#
#      latitude  longitude       date   number  ... precip_probability  \
# 12   41.29873  -73.73717 2010-09-01  31940.0  ...                0.0
# 24   36.25466  -86.15759 2010-07-16  28005.0  ...              100.0
# 142  41.94512  -73.87915 2010-02-15  26205.0  ...              100.0
# 150  44.22388  -73.87529 2010-08-06  64192.0  ...                0.0
# 156  43.30679  -74.15429 2010-09-24  28570.0  ...                0.0
#
#           precip_type  pressure  \
# 12                NaN    1017.0
# 24           ['rain']    1015.3
# 142  ['rain', 'snow']    1005.3
# 150               NaN    1005.2
# 156               NaN    1013.7
#
#                                                summary  \
# 12                Clear conditions throughout the day.
# 24   Partly cloudy throughout the day with late aft...
# 142  Clearing in the afternoon with late afternoon ...
# 150                  Partly cloudy throughout the day.
# 156                  Partly cloudy throughout the day.
#
#                        conditions  uv_index  visibility  wind_bearing  \
# 12                          Clear       NaN         6.7         262.6
# 24         Rain, Partially cloudy       NaN         9.7         193.0
# 142  Snow, Rain, Partially cloudy       NaN         9.3         243.2
# 150              Partially cloudy       NaN         9.9         292.3
# 156              Partially cloudy       NaN         9.5         186.5
#
#      wind_speed                   location
# 12          6.3  POINT(-73.73717 41.29873)
# 24         11.4  POINT(-86.15759 36.25466)
# 142         8.6  POINT(-73.87915 41.94512)
# 150        13.4  POINT(-73.87529 44.22388)
# 156        13.7  POINT(-74.15429 43.30679)
#
# [5 rows x 30 columns]

# %%
# num_rows = min(500, len(cleaned_df))
# # trying to make the map smaller. didn't seem to work, commenting out 
# from branca.element import Figure
# fig = Figure(width=500, height=300) 
# fig.add_child(m)
# fig


if not df_2010.empty:
    first_point = df_2010.iloc[0]
    m = folium.Map(location=[first_point['latitude'], first_point['longitude']], zoom_start=5)

 
    for index, row in df_2010.iloc[:num_rows].iterrows():
        folium.Marker(location=[row['latitude'], row['longitude']]).add_to(m)


    display(m)
else:
    print("You messed up, buddy.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b3537f68295de56343d7a649b53da59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b3537f68295de56343d7a649b53da59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b3537f68295de56343d7a649b53da59 = L.map(
#                 &quot;map_6b3537f68295de56343d7a649b53da59&quot;,
#                 {
#                     center: [41.29873, -73.73717],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09132ca8deba6af0af56b24b7c388978 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_6caee8a81b99a10325cb8a7202dccd74 = L.marker(
#                 [41.29873, -73.73717],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_6680c6e378e5f9c03522996651ca0a45 = L.marker(
#                 [36.25466, -86.15759],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_350e63ca5ddcd464afc9fa845f320ff4 = L.marker(
#                 [41.94512, -73.87915],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_77e5cf7bc71977cd69c89e4dde4b349b = L.marker(
#                 [44.22388, -73.87529],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_02a9e23a596eff7d0bffb5094e0414eb = L.marker(
#                 [43.30679, -74.15429],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_465a14a0d075d13c851f6fe134401d8d = L.marker(
#                 [38.69322, -83.12891],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_b0a21a82b1a2e5f80c92d1d6f6f3139c = L.marker(
#                 [40.90177, -81.26729],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_263014520ecbadb99fb53165dce13155 = L.marker(
#                 [41.16984, -81.64181],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_7008fbae89dc4bfe8547dc59effbc195 = L.marker(
#                 [40.11682, -81.4936],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_e59ad670e605b4f8f5aacc3dc2cdedb1 = L.marker(
#                 [40.36207, -81.18504],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_1390dc314f5fee2234a9ba61b7df5a2f = L.marker(
#                 [38.64301, -83.69977],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_ecb5822e3cfe6851828c248d7bf8f2ac = L.marker(
#                 [39.59947, -82.63536],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_0ffeb4a836c156185c716316ffdd9199 = L.marker(
#                 [34.021, -94.4435],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_83253b548ebcb2489db3dc049246f9c9 = L.marker(
#                 [34.76134, -98.61497],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_90391549095d24e7f68d360773f3249a = L.marker(
#                 [35.0, -99.0],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_84f849da1bfda517a5a3eb6ea3a64e19 = L.marker(
#                 [41.51954, -78.87955],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_0f45123769ef588b4126c4b45714af2d = L.marker(
#                 [32.755, -98.0],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_d33cb41ef2f61f07d607d2fc171130a8 = L.marker(
#                 [29.30877, -97.47971],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_733c9f62b0a4f12792a2dff48dca5e03 = L.marker(
#                 [38.56546, -79.14478],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_f49feb6d286d2f4f26942d87a2f98d34 = L.marker(
#                 [45.86883, -121.4813],
#                 {}
#             ).addTo(map_6b3537f68295de56343d7a649b53da59);
#
#
#             var marker_c9d4da4f8e37b35c0eaed45c11bb5763 = L.marker(
#                 [46.49406, -122.5319],
#                 {

# %%
df_until_2010 = cleaned_df[cleaned_df['date'].dt.year <= 2010]
num_rows = min(10000, len(df_until_2010))

# %%
if not df_until_2010.empty:
    first_point = df_until_2010.iloc[0]
    m = folium.Map(location=[first_point['latitude'], first_point['longitude']], zoom_start=5)

 
    for index, row in df_2010.iloc[:num_rows].iterrows():
        folium.Marker(location=[row['latitude'], row['longitude']]).add_to(m)


    display(m)
else:
    print("You messed up, buddy.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69a585c92b96ca3c4db2857313f3aa9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69a585c92b96ca3c4db2857313f3aa9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69a585c92b96ca3c4db2857313f3aa9e = L.map(
#                 &quot;map_69a585c92b96ca3c4db2857313f3aa9e&quot;,
#                 {
#                     center: [37.58135, -81.29745],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fe642a217c12e18ba3e10b005958469 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_0924cd457259ae8c25589cf8c840e9dc = L.marker(
#                 [41.29873, -73.73717],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_d8f5d7142e47e14c43a53c4edc77f772 = L.marker(
#                 [36.25466, -86.15759],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_e05be1f2fd412a8cc7f666852d4e3b0e = L.marker(
#                 [41.94512, -73.87915],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_250c5170cfa764f8059dbf26d12b6ee3 = L.marker(
#                 [44.22388, -73.87529],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_0b6dc2553553690f43bd974c808d266f = L.marker(
#                 [43.30679, -74.15429],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_6da2eaa4c301314e578265f9fab3bcc5 = L.marker(
#                 [38.69322, -83.12891],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_f7000b8b2c5737e35a20cf136f2983ee = L.marker(
#                 [40.90177, -81.26729],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_ff5b33c8069f38dd143202c1b587d4c3 = L.marker(
#                 [41.16984, -81.64181],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_2e40dd215b6f60cc716731bf98d90e7e = L.marker(
#                 [40.11682, -81.4936],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_68bcc3a371415ae99af5b5ab5c4605cc = L.marker(
#                 [40.36207, -81.18504],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_49b458fbbe0c38d4441cf938d3170b6e = L.marker(
#                 [38.64301, -83.69977],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_39d42eb3ee6b0c193612358e2ce4c0be = L.marker(
#                 [39.59947, -82.63536],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_68a82b8367da52598b3c76a711436115 = L.marker(
#                 [34.021, -94.4435],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_14fd18579ef480e8b715920aef273ffd = L.marker(
#                 [34.76134, -98.61497],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_648e661989c98a5686af05798c6dbad6 = L.marker(
#                 [35.0, -99.0],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_592711f8e615546e8faf7aec2d56a75e = L.marker(
#                 [41.51954, -78.87955],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_4c7b58410998141fae78884e98875602 = L.marker(
#                 [32.755, -98.0],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_3a72d027a37e6f93e9f9b245a22ae0bf = L.marker(
#                 [29.30877, -97.47971],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_f541272404e0e1190ece296e0f23a078 = L.marker(
#                 [38.56546, -79.14478],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_9f04db6b481ccb5aebed56292d5c9ebc = L.marker(
#                 [45.86883, -121.4813],
#                 {}
#             ).addTo(map_69a585c92b96ca3c4db2857313f3aa9e);
#
#
#             var marker_cb718b6a411b1338cb9bfcc2ffc8964d = L.marker(
#                 [46.49406, -122.5319],
#                 {
