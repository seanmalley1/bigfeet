# %% [markdown]
# https://www.geeksforgeeks.org/generating-word-cloud-python/
# https://towardsdatascience.com/how-to-create-beautiful-word-clouds-in-python-cfcf85141214
# https://github.com/nltk/nltk/wiki/FAQ

# %%
import pandas as pd
df_ufo = pd.read_csv('C:\\Users\\seanm\\Proton Drive\\sean.malley1\\Other computers\\EXACTLY5CATS\\d10\\Projects\\bigfeet\\data\\nuforc_reports.csv')
df_fire = pd.read_csv('C:\\Users\\seanm\\Proton Drive\\sean.malley1\\Other computers\\EXACTLY5CATS\\d10\\Projects\\bigfeet\\data\\fire_dd.csv')

# df_big = pd.read_csv('F:\\d10\\Projects\\bigfoots-ufos-ghosts-oh-my\\data\\bfro_reports_geocoded.csv')

# %%
df_fire.head()
# Out:
#   Date/Time - Peak Brightness (UT) latitude longitude  Altitude (km)  \
# 0                 11/21/2009 20:53    22.0S     29.2E           38.0
# 1                   1/9/2015 10:41     2.0N     28.8E           36.0
# 2                  5/16/2014 12:42    44.2S    176.2W           44.0
# 3                   8/23/2014 6:29    61.7S    132.6E           22.2
# 4                  12/12/2014 6:48    33.5N    144.9E           26.3
#
#    Velocity (km/s)  Velocity Components (km/s): vx  \
# 0             32.1                             3.0
# 1              NaN                           -10.7
# 2              NaN                            14.4
# 3             16.2                            -2.3
# 4              NaN                            11.5
#
#    Velocity Components (km/s): vy  Velocity Components (km/s): vz  \
# 0                           -17.0                           -27.0
# 1                            -7.6                            11.6
# 2                             4.6                             6.5
# 3                             5.7                            16.5
# 4                            -2.8                            -2.2
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0               1.000000e+13                                18.00
# 1               1.390000e+11                                 0.41
# 2               3.090000e+11                                 0.82
# 3               3.820000e+12                                 7.60
# 4               3.300000e+10                                 0.11

# %%
df_fire['latitude'] = df_fire['latitude'].apply(lambda x: float(str(x)[:-1]) if str(x)[-1] in ['N', 'S'] else float(str(x)))
df_fire['longitude'] = df_fire['longitude'].apply(lambda x: float(str(x)[:-1]) if str(x)[-1] in ['E', 'W'] else float(str(x)))

# %%
df_ufo['latitude'] = df_ufo['city_latitude']
df_ufo['longitude'] = df_ufo['city_longitude']
df_ufo.drop(columns=['city_latitude', 'city_longitude'], inplace=True)
df_ufo.dropna(subset=['summary'], inplace=True)
df_ufo.dropna(subset=['latitude'], inplace=True)
df_ufo.dropna(subset=['longitude'], inplace=True)
df_ufo.dropna(subset=['shape'], inplace=True)
df_ufo.head()

# %%
df_fire.dropna(subset=['latitude'], inplace=True)
df_fire.dropna(subset=['longitude'], inplace=True)

df_fire.head()
# Out:
#   Date/Time - Peak Brightness (UT)  latitude  longitude  Altitude (km)  \
# 0                 11/21/2009 20:53      22.0       29.2           38.0
# 1                   1/9/2015 10:41       2.0       28.8           36.0
# 2                  5/16/2014 12:42      44.2      176.2           44.0
# 3                   8/23/2014 6:29      61.7      132.6           22.2
# 4                  12/12/2014 6:48      33.5      144.9           26.3
#
#    Velocity (km/s)  Velocity Components (km/s): vx  \
# 0             32.1                             3.0
# 1              NaN                           -10.7
# 2              NaN                            14.4
# 3             16.2                            -2.3
# 4              NaN                            11.5
#
#    Velocity Components (km/s): vy  Velocity Components (km/s): vz  \
# 0                           -17.0                           -27.0
# 1                            -7.6                            11.6
# 2                             4.6                             6.5
# 3                             5.7                            16.5
# 4                            -2.8                            -2.2
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0               1.000000e+13                                18.00
# 1               1.390000e+11                                 0.41
# 2               3.090000e+11                                 0.82
# 3               3.820000e+12                                 7.60
# 4               3.300000e+10                                 0.11

# %%
df_fire.head()
# Out:
#   Date/Time - Peak Brightness (UT)  latitude  longitude  Altitude (km)  \
# 0                 11/21/2009 20:53      22.0       29.2           38.0
# 1                   1/9/2015 10:41       2.0       28.8           36.0
# 2                  5/16/2014 12:42      44.2      176.2           44.0
# 3                   8/23/2014 6:29      61.7      132.6           22.2
# 4                  12/12/2014 6:48      33.5      144.9           26.3
#
#    Velocity (km/s)  Velocity Components (km/s): vx  \
# 0             32.1                             3.0
# 1              NaN                           -10.7
# 2              NaN                            14.4
# 3             16.2                            -2.3
# 4              NaN                            11.5
#
#    Velocity Components (km/s): vy  Velocity Components (km/s): vz  \
# 0                           -17.0                           -27.0
# 1                            -7.6                            11.6
# 2                             4.6                             6.5
# 3                             5.7                            16.5
# 4                            -2.8                            -2.2
#
#    Total Radiated Energy (J)  Calculated Total Impact Energy (kt)
# 0               1.000000e+13                                18.00
# 1               1.390000e+11                                 0.41
# 2               3.090000e+11                                 0.82
# 3               3.820000e+12                                 7.60
# 4               3.300000e+10                                 0.11

# %%
import folium

# %%
df_fire.head()

# %%
# df_fire = df.dropna(subset=['latitude', 'longitude'])
# 200 points at first because computer froze last time 
num_rows = min(2000, len(df_fire))


if not df_fire.empty:
    first_point = df_fire.iloc[0]
    m = folium.Map(location=[first_point['latitude'], first_point['longitude']], zoom_start=5)

    # 1st 200 rows to be marked
    for index, row in df_fire.iloc[:num_rows].iterrows():
        folium.Marker(location=[row['latitude'], row['longitude']]).add_to(m)

  

    
    display(m)
else:
    print("you messed up, buddy.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fe16285e433e5664bf3c23eb7f8d5cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fe16285e433e5664bf3c23eb7f8d5cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fe16285e433e5664bf3c23eb7f8d5cd = L.map(
#                 &quot;map_3fe16285e433e5664bf3c23eb7f8d5cd&quot;,
#                 {
#                     center: [22.0, 29.2],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6abdf2dc39116a78a96a0e53f3db53f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_dc1193d24810773f1c42d9a1938394be = L.marker(
#                 [22.0, 29.2],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_7369a65dcec4e07c2185103b08d45118 = L.marker(
#                 [2.0, 28.8],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_6c13c06161622e60ed06db6c4c3011c6 = L.marker(
#                 [44.2, 176.2],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_128180097d3e49bacb7d90d046aefd73 = L.marker(
#                 [61.7, 132.6],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_0c7140e6c2c8d4a7212db2b34c8b25a2 = L.marker(
#                 [33.5, 144.9],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_8303d189aab9e6ebe066b0a1fa9671a2 = L.marker(
#                 [49.2, 172.2],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_57e6e1fcded84045e1071ae424790cf7 = L.marker(
#                 [65.6, 138.4],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_6d85f40d4a3c7b58b3aa8afbc3b60442 = L.marker(
#                 [8.0, 11.2],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_459db12bd81a46a184ea313e6a9c37bc = L.marker(
#                 [4.6, 66.3],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_8a400654f18cfd86c55d3c144b7e7ccb = L.marker(
#                 [32.8, 165.1],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_13516ca0ff7881d2aa40311548e39d04 = L.marker(
#                 [22.7, 150.0],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_547c571d911184167bd47b88d28ae5d4 = L.marker(
#                 [12.4, 122.4],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_61b5e6d2d3709531d1bd334f5652aba2 = L.marker(
#                 [43.1, 115.8],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_080e24f6909d1e9d81c163dfdc718a74 = L.marker(
#                 [21.0, 178.5],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_717f858ce2e9f56fea274331f4abc30e = L.marker(
#                 [38.0, 158.0],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_9fb21ad72358f58ce0ccb4cea96ee35d = L.marker(
#                 [45.7, 26.9],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_51e8da7bcdacd763394f788903d9df23 = L.marker(
#                 [60.3, 64.6],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_9540222613906eb4098e72a1bb82d47c = L.marker(
#                 [3.2, 45.4],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_72c422fd05da2cf7dd557acadfe151fc = L.marker(
#                 [18.5, 141.8],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_d9736ee8d0eb5dc99708f378ee2cf8fc = L.marker(
#                 [39.5, 2.0],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_19dac40d77fc7f7acd504450af870fab = L.marker(
#                 [68.2, 24.0],
#                 {}
#             ).addTo(map_3fe16285e433e5664bf3c23eb7f8d5cd);
#
#
#             var marker_4c5d68bea1f2f37eb8cdd557a80e0869 = L.marker(
#                 [0.0, 111.8],

# %%
# df_ufo = df.dropna(subset=['latitude', 'longitude'])
# 200 points at first because computer froze last time 
num_rows = min(500, len(df_ufo))


if not df_ufo.empty:
    first_point = df_ufo.iloc[0]
    m = folium.Map(location=[first_point['latitude'], first_point['longitude']], zoom_start=5)

    # 1st 200 rows to be marked
    for index, row in df_ufo.iloc[:num_rows].iterrows():
        folium.Marker(location=[row['latitude'], row['longitude']]).add_to(m)

  

    
    display(m)
else:
    print("you messed up, buddy.")

# %%
def clean_data(df):
    
    # df = df[df['state'] == "Maine"]
    
    df = df.groupby(['state']).agg(state_count=('state', 'count')).reset_index()
    return df

df_clean = clean_data(df.copy())
df_clean.head(49)

def clean_data(df_clean):
    
    df_clean = df_clean.sort_values(['state_count'], ascending=[False])
    return df_clean

df_clean_1 = clean_data(df_clean.copy())
df_clean_1.head(55)

# %%
state_shape_data = df_ufo.groupby(['state', 'shape']).size()


print(state_shape_data)

# %%
grouped_data = df_ufo.groupby(['state', 'shape']).size().reset_index(name='count')


sorted_data = grouped_data.sort_values(['state', 'count'], ascending=[True, False])


def top_n_per_group(df, n=5):
    return df.groupby('state').head(n)

top_shapes_per_state = top_n_per_group(sorted_data)


print(top_shapes_per_state)

# %%
grouped_data = df_ufo.groupby(['state', 'shape']).size().reset_index(name='count')


sorted_data = grouped_data.sort_values(['state', 'count'], ascending=[True, False])


most_common_shape_per_state = sorted_data.groupby('state').head(1)


print(most_common_shape_per_state)

# %%
us_states = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 
    'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 
    'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 
    'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 
    'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
]


filtered_data = df_ufo[df_ufo['state'].isin(us_states)]


grouped_data = filtered_data.groupby(['state', 'shape']).size().reset_index(name='count')


sorted_data = grouped_data.sort_values(['state', 'count'], ascending=[True, False])


most_common_shape_per_state = sorted_data.groupby('state').head(3)


print(most_common_shape_per_state)

# %%
us_states = [
    'AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 
    'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 
    'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 
    'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 
    'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
]


filtered_data = df_ufo[(df_ufo['state'].isin(us_states)) & (df_ufo['shape'] != 'light')]


grouped_data = filtered_data.groupby(['state', 'shape']).size().reset_index(name='count')


sorted_data = grouped_data.sort_values(['state', 'count'], ascending=[True, False])


most_common_shape_per_state = sorted_data.groupby('state').head(2)


print(most_common_shape_per_state)

# %%
# !pip install Basemap

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap


state_coords = {
    'AL': (32.806671, -86.791130), 'AK': (61.370716, -152.404419), 'AZ': (33.729759, -111.431221),
    'AR': (34.969704, -92.373123), 'CA': (36.116203, -119.681564), 'CO': (39.059811, -105.311104),
    'CT': (41.597782, -72.755371), 'DE': (39.318523, -75.507141), 'FL': (27.766279, -81.686783),
    'GA': (33.040619, -83.643074), 'HI': (21.094318, -157.498337), 'ID': (44.240459, -114.478828),
    'IL': (40.349457, -88.986137), 'IN': (39.849426, -86.258278), 'IA': (42.011539, -93.210526),
    'KS': (38.526600, -96.726486), 'KY': (37.668140, -84.670067), 'LA': (31.169546, -91.867805),
    'ME': (44.693947, -69.381927), 'MD': (39.063946, -76.802101), 'MA': (42.230171, -71.530106),
    'MI': (43.326618, -84.536095), 'MN': (45.694454, -93.900192), 'MS': (32.741646, -89.678696),
    'MO': (38.456085, -92.288368), 'MT': (46.921925, -110.454353), 'NE': (41.125370, -98.268082),
    'NV': (38.313515, -117.055374), 'NH': (43.452492, -71.563896), 'NJ': (40.298904, -74.521011),
    'NM': (34.840515, -106.248482), 'NY': (42.165726, -74.948051), 'NC': (35.630066, -79.806419),
    'ND': (47.528912, -99.784012), 'OH': (40.388783, -82.764915), 'OK': (35.565342, -96.928917),
    'OR': (44.572021, -122.070938), 'PA': (40.590752, -77.209755), 'RI': (41.680893, -71.511780),
    'SC': (33.856892, -80.945007), 'AK': (64.200841, -149.493673), 'SD': (44.299782, -99.438828),
    'TN': (35.747845, -86.692345), 'TX': (31.054487, -97.563461), 'UT': (40.150032, -111.862434),
    'VT': (44.045876, -72.710686), 'VA': (37.769337, -78.169968), 'WA': (47.400902, -121.490494),
    'WV': (38.491226, -80.954455), 'WI': (44.268543, -89.616508), 'WY': (42.755966, -107.302490)
}

shape_to_symbol = {
    'circle': 'o',  
    'triangle': '^',  
    'sphere': 'o',  
    
}


plt.figure(figsize=(14, 8))
m = Basemap(llcrnrlon=-130, llcrnrlat=20, urcrnrlon=-65, urcrnrlat=50, projection='lcc', lat_1=33, lat_2=45, lon_0=-95)


m.drawcoastlines()
m.drawcountries()
m.drawstates()


for index, row in most_common_shape_per_state.iterrows():
    state = row['state']
    shape = row['shape']
    if state in state_coords:
        lat, lon = state_coords[state]
        x, y = m(lon, lat)
        symbol = shape_to_symbol.get(shape, 'x')
        m.plot(x, y, symbol, markersize=10, label=shape if index == 0 else "", color='red')

plt.legend(loc='lower left', bbox_to_anchor=(1, 0))
plt.show()
