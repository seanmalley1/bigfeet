# %% [markdown]
# All bigfoot

# %%
import pandas as pd

# %%
df.head()
# Out:
#                                             observed  \
# 0  I am not sure how relevant this report will be...
# 1  I don't know if what I saw was two bigfoots or...
# 2  My family and I went to Ludlow, Vermont for Co...
# 3  It was spring break 1984 and I was 16 at the t...
# 4  It was the winter of 1996 and we were on our w...
#
#                                     location_details           county  \
# 0  We were on our way to Rapid City, so we were h...  Washakie County
# 1  Heading to the deep mine Poca #2, the airshaft...   Wyoming County
# 2  It's off Rt 100 outside of Ludlow Vermont. It ...   Windsor County
# 3  Wythe county Virginia near Wytheville, looking...     Wythe County
# 4  Hwy 182, Wood County Between Quitman, Texas an...      Wood County
#
#            state  season                                              title  \
# 0        Wyoming  Summer                                                NaN
# ...

# %%
df= pd.read_csv('F:\\d10\\Projects\\bigfeet\data\\bfro_reports_geocoded.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['moon_phase'] = pd.to_numeric(df['moon_phase'], errors='coerce')


plt.figure(figsize=(10, 6))  
plt.hist(df['moon_phase'], bins=8, color='skyblue', edgecolor='black')  
plt.title('phase of moon distributuion')
plt.xlabel('Moon Phase')
plt.ylabel('Frequency')
plt.grid(True)  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['pressure'] = pd.to_numeric(df['pressure'], errors='coerce')


plt.figure(figsize=(10, 6))  
plt.hist(df['pressure'], bins=20, color='skyblue', edgecolor='black')  
plt.title('Pressure distro')
plt.xlabel('barametric pressure')
plt.ylabel('Frequency')
plt.grid(True)  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['cloud_cover'] = pd.to_numeric(df['cloud_cover'], errors='coerce')


plt.figure(figsize=(10, 6))  
plt.hist(df['cloud_cover'], bins=20, color='skyblue', edgecolor='black')  
plt.title('weather - cloud cover')
plt.xlabel('cloud cover')
plt.ylabel('Frequency')
plt.grid(True)  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['temperature_mid'] = pd.to_numeric(df['temperature_mid'], errors='coerce')


plt.figure(figsize=(10, 6))  
plt.hist(df['temperature_mid'], bins=20, color='skyblue', edgecolor='black')  
plt.title('temperature_mid histogram')
plt.xlabel('temperature_mid range')
plt.ylabel('Frequency')
plt.grid(True)  
plt.show()

# %%
Population / Per capita calcuations

# %%
df_pop = pd.read_csv('F:\\d10\\Projects\\bigfeet\\data\\bfro_reports_geocoded.csv')

# %%
df.head()
# Out:
#                                             observed  \
# 0  I am not sure how relevant this report will be...
# 1  I don't know if what I saw was two bigfoots or...
# 2  My family and I went to Ludlow, Vermont for Co...
# 3  It was spring break 1984 and I was 16 at the t...
# 4  It was the winter of 1996 and we were on our w...
#
#                                     location_details           county  \
# 0  We were on our way to Rapid City, so we were h...  Washakie County
# 1  Heading to the deep mine Poca #2, the airshaft...   Wyoming County
# 2  It's off Rt 100 outside of Ludlow Vermont. It ...   Windsor County
# 3  Wythe county Virginia near Wytheville, looking...     Wythe County
# 4  Hwy 182, Wood County Between Quitman, Texas an...      Wood County
#
#            state  season                                              title  \
# 0        Wyoming  Summer                                                NaN
# ...
