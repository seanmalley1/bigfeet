# %% [markdown]
# Population / Per capita calcuations

# %% [markdown]
# Bigfoot Calcs.

# %%
import pandas as pd

# %%
df = pd.read_csv('F:\\d10\\Projects\\bigfeet\\data\\bfro_reports_geocoded.csv')
df_pop = pd.read_csv('F:\\d10\\Projects\\bigfeet\\data\\census_state_pop.csv')

state_counts = df['state'].value_counts().reset_index()
state_counts.columns = ['state', 'count']


merged_df = pd.merge(state_counts, df_pop, left_on='state', right_on='NAME')

merged_df['entries_per_capita'] = merged_df['count'] / merged_df['POPESTIMATE2023']
state_counts = merged_df[['state', 'count', 'entries_per_capita']].sort_values(by='entries_per_capita', ascending=False)



df_final = pd.merge(df, state_counts[['state', 'entries_per_capita']], on='state', how='left')


output_path_final = 'F:\\d10\\Projects\\bigfeet\\data\\export\\bigfeet_capita_simple.csv'
state_counts.to_csv(output_path_final, index=False)

# %%
df_final.head()
# Out:
#                                             observed  \
# 0  I am not sure how relevant this report will be...
# 1  I don't know if what I saw was two bigfoots or...
# 2  My family and I went to Ludlow, Vermont for Co...
# 3  It was spring break 1984 and I was 16 at the t...
# 4  It was the winter of 1996 and we were on our w...
#
#                                     location_details           county  \
# 0  We were on our way to Rapid City, so we were h...  Washakie County
# 1  Heading to the deep mine Poca #2, the airshaft...   Wyoming County
# 2  It's off Rt 100 outside of Ludlow Vermont. It ...   Windsor County
# 3  Wythe county Virginia near Wytheville, looking...     Wythe County
# 4  Hwy 182, Wood County Between Quitman, Texas an...      Wood County
#
#            state  season                                              title  \
# 0        Wyoming  Summer                                                NaN
# 1  West Virginia  Winter  Report 13237: Daylight sighting near an abando...
# 2        Vermont    Fall  Report 13285: Evening sighting by motorists on...
# 3       Virginia  Spring  Report 2285: Boy sees "Bigfoot" in the woods w...
# 4          Texas  Winter  Report 2048: Night time road crossing observation
#
#    latitude  longitude        date   number  ...       precip_type pressure  \
# 0       NaN        NaN         NaN    798.0  ...               NaN      NaN
# 1  37.58135  -81.29745  2005-12-03  13237.0  ...  ['rain', 'snow']   1018.7
# 2  43.46540  -72.70510  2005-10-08  13285.0  ...          ['rain']   1011.8
# 3  37.22647  -81.09017  1984-04-08   2285.0  ...               NaN   1020.9
# 4  32.79430  -95.54250  1996-12-22   2048.0  ...               NaN      NaN
#
#                                              summary  \
# 0                                                NaN
# 1  Partly cloudy throughout the day with late aft...
# 2  Cloudy skies throughout the day with a chance ...
# 3                  Partly cloudy throughout the day.
# 4                  Partly cloudy throughout the day.
#
#                      conditions  uv_index  visibility  wind_bearing  \
# 0                           NaN       NaN         NaN           NaN
# 1  Snow, Rain, Partially cloudy       NaN         9.3         168.1
# 2                Rain, Overcast       NaN         5.0         356.2
# 3              Partially cloudy       NaN        13.0         107.3
# 4              Partially cloudy       NaN        10.5         180.4
#
#    wind_speed                   location  entries_per_capita
# 0         NaN                        NaN            0.000046
# 1        17.1  POINT(-81.29745 37.58135)            0.000059
# 2         7.6    POINT(-72.7051 43.4654)            0.000015
# 3        11.5  POINT(-81.09017 37.22647)            0.000009
# 4        20.8    POINT(-95.5425 32.7943)            0.000008
#
# [5 rows x 31 columns]

# %%
state_counts.head(50)
# Out:
#              state  count  entries_per_capita
# 0       Washington    610            0.000078
# 4           Oregon    249            0.000059
# 14   West Virginia    104            0.000059
# 17           Idaho     97            0.000049
# 36         Wyoming     27            0.000046
# 29         Montana     51            0.000045
# 15        Arkansas    103            0.000034
# 39          Alaska     21            0.000029
# 3             Ohio    306            0.000026
# 8         Missouri    159            0.000026
# 13        Kentucky    114            0.000025
# 16        Oklahoma     99            0.000024
# 7         Michigan    217            0.000022
# 10        Colorado    127            0.000022
# 32      New Mexico     42            0.000020
# 5         Illinois    238            0.000019
# 19         Alabama     95            0.000019
# 28            Iowa     56            0.000017
# 27            Utah     59            0.000017
# 44         Vermont     10            0.000015
# 30          Kansas     45            0.000015
# 21       Wisconsin     87            0.000015
# 43    South Dakota     13            0.000014
# 2          Florida    306            0.000014
# 18       Tennessee     96            0.000013
# 40           Maine     18            0.000013
# 25       Minnesota     73            0.000013
# 9          Georgia    129            0.000012
# 24         Indiana     79            0.000012
# 22         Arizona     85            0.000011
# 1       California    422            0.000011
# 42   New Hampshire     14            0.000010
# 23        Virginia     81            0.000009
# 11    Pennsylvania    120            0.000009
# 33       Louisiana     41            0.000009
# 20  North Carolina     90            0.000008
# 31  South Carolina     43            0.000008
# 41        Nebraska     15            0.000008
# 6            Texas    231            0.000008
# 37     Mississippi     22            0.000007
# 26      New Jersey     68            0.000007
# 12        New York    114            0.000006
# 38     Connecticut     21            0.000006
# 34        Maryland     35            0.000006
# 48    North Dakota      4            0.000005
# 46        Delaware      5            0.000005
# 47    Rhode Island      5            0.000005
# 35   Massachusetts     29            0.000004
# 45          Nevada      7            0.000002

# %%
geo_df.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS          NAME LSAD  \
# 0      31  01779792  0400000US31    31     NE      Nebraska   00
# 1      53  01779804  0400000US53    53     WA    Washington   00
# 2      35  00897535  0400000US35    35     NM    New Mexico   00
# 3      46  01785534  0400000US46    46     SD  South Dakota   00
# 4      48  01779801  0400000US48    48     TX         Texas   00
#
#           ALAND       AWATER  \
# 0  198956658395   1371829134
# 1  172112588220  12559278850
# 2  314196306401    728776523
# 3  196346981786   3382720225
# 4  676653171537  19006305260
#
#                                             geometry
# 0  POLYGON ((-104.05351 41.15726, -104.05267 41.2...
# 1  MULTIPOLYGON (((-122.32834 48.02134, -122.3217...
# 2  POLYGON ((-109.05017 31.48000, -109.04984 31.4...
# 3  POLYGON ((-104.05770 44.99743, -104.05021 44.9...
# 4  POLYGON ((-106.64548 31.89867, -106.64084 31.9...

# %% [markdown]
# bigfeet map.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt


df_bf_map = pd.read_csv('F:\\d10\\Projects\\bigfeet\\data\\export\\combined_capita.csv')


geo_df = gpd.read_file('F:\\d10\\Projects\\bigfeet\\data\\states.shp')


bf_merged_df = geo_df.set_index('NAME').join(df_bf_map.set_index('state'))


fig, ax = plt.subplots(1, 1, figsize=(15, 10))
bf_merged_df.plot(column='bigfeets_per_capita', ax=ax, legend=True,
               legend_kwds={'label': "Bigfeets Per Capita by State",
                            'orientation': "horizontal"})

plt.show()
