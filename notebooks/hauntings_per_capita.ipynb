# %% [markdown]
# Hauntings per capita

# %%
import pandas as pd

# %%
df = pd.read_csv('F:\\d10\\Projects\\bigfeet\\data\\haunted_places_2.csv')
df_pop = pd.read_csv('F:\\d10\\Projects\\bigfeet\\data\\census_state_pop.csv')

state_counts = df['state'].value_counts().reset_index()
state_counts.columns = ['state', 'count']


merged_df = pd.merge(state_counts, df_pop, left_on='state', right_on='NAME')

merged_df['entries_per_capita'] = merged_df['count'] / merged_df['POPESTIMATE2023']
state_counts = merged_df[['state', 'count', 'entries_per_capita']].sort_values(by='entries_per_capita', ascending=False)



df_final = pd.merge(df, state_counts[['state', 'entries_per_capita']], on='state', how='left')


output_path_final = 'F:\\d10\\Projects\\bigfeet\\data\\export\\hauntings_per_capita.csv'
df_final.to_csv(output_path_final, index=False)

# %%
state_counts.head(50)
# Out:
#              state  count  entries_per_capita
# 37         Wyoming     76            0.000130
# 42         Vermont     63            0.000097
# 7         Kentucky    370            0.000082
# 38    South Dakota     75            0.000082
# 44    North Dakota     58            0.000074
# 35          Hawaii     96            0.000067
# 40    Rhode Island     68            0.000062
# 33   West Virginia    106            0.000060
# 32        Nebraska    111            0.000056
# 3         Michigan    529            0.000053
# 23            Iowa    169            0.000053
# 18        Oklahoma    211            0.000052
# 39   New Hampshire     72            0.000051
# 8          Indiana    351            0.000051
# 21     Connecticut    185            0.000051
# 11        Missouri    314            0.000051
# 2     Pennsylvania    649            0.000050
# 9    Massachusetts    342            0.000049
# 13       Wisconsin    274            0.000046
# 14         Alabama    224            0.000044
# 49          Alaska     32            0.000044
# 30          Kansas    123            0.000042
# 45           Maine     57            0.000041
# 4             Ohio    477            0.000040
# 29            Utah    134            0.000039
# 31        Arkansas    119            0.000039
# 47         Montana     42            0.000037
# 36      New Mexico     78            0.000037
# 28          Oregon    155            0.000037
# 48        Delaware     37            0.000036
# 41           Idaho     66            0.000034
# 6         Illinois    395            0.000031
# 24  South Carolina    168            0.000031
# 15       Tennessee    221            0.000031
# 25        Colorado    166            0.000028
# 26       Minnesota    162            0.000028
# 16      Washington    218            0.000028
# 22        Maryland    170            0.000028
# 0       California   1070            0.000027
# 12         Georgia    289            0.000026
# 5         New York    459            0.000023
# 1            Texas    696            0.000023
# 20        Virginia    192            0.000022
# 34       Louisiana     99            0.000022
# 43     Mississippi     63            0.000021
# 27         Arizona    156            0.000021
# 19      New Jersey    194            0.000021
# 17  North Carolina    211            0.000019
# 46          Nevada     56            0.000018
# 10         Florida    328            0.000015
